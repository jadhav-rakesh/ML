# %% [markdown]
# <a href="https://colab.research.google.com/github/jadhav-rakesh/ML/blob/main/ds3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

url = "https://raw.githubusercontent.com/chrisalbon/sim_data/master/titanic.csv"

df = pd.read_csv(url)

df.head(5)
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0

# %%
# create a new dataframe

dictn = {"Name":["Jacky Jackson", "Steven Stevnson"],
         "Age":[38, 25],
         "Driver":[True, False]}

df = pd.DataFrame(dictn)

df
# Out:
#               Name  Age  Driver
# 0    Jacky Jackson   38    True
# 1  Steven Stevnson   25   False

# %%
df["Eyes"] = ["Brown", "Blue"]
df
# Out:
#               Name  Age  Driver   Eyes
# 0    Jacky Jackson   38    True  Brown
# 1  Steven Stevnson   25   False   Blue

# %%
#view some characteristics of a DataFrame

url = 'https://raw.githubusercontent.com/chrisalbon/sim_data/master/titanic.csv'

df = pd.read_csv(url)

df.head(2)
# Out:
#                            Name PClass   Age     Sex  Survived  SexCode
# 0  Allen, Miss Elisabeth Walton    1st  29.0  female         1        1
# 1   Allison, Miss Helen Loraine    1st   2.0  female         0        1

# %%
df.shape
# Out:
# (1313, 6)

# %%
df.describe()
# Out:
#               Age     Survived      SexCode
# count  756.000000  1313.000000  1313.000000
# mean    30.397989     0.342727     0.351866
# std     14.259049     0.474802     0.477734
# min      0.170000     0.000000     0.000000
# 25%     21.000000     0.000000     0.000000
# 50%     28.000000     0.000000     0.000000
# 75%     39.000000     1.000000     1.000000
# max     71.000000     1.000000     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313 entries, 0 to 1312
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      1313 non-null   object
#  1   PClass    1313 non-null   object
#  2   Age       756 non-null    float64
#  3   Sex       1313 non-null   object
#  4   Survived  1313 non-null   int64
#  5   SexCode   1313 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 61.7+ KB

# %%
#need to select a specific subset data or slices of a DataFrame.

df.iloc[1:4]
# Out:
#                                             Name PClass   Age     Sex  \
# 1                    Allison, Miss Helen Loraine    1st   2.0  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.0    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
#
#    Survived  SexCode
# 1         0        1
# 2         0        0
# 3         0        1

# %%
#set index

df = df.set_index(df["Name"])

df.loc["Allen, Miss Elisabeth Walton"]
# Out:
# Name        Allen, Miss Elisabeth Walton
# PClass                               1st
# Age                                 29.0
# Sex                               female
# Survived                               1
# SexCode                                1
# Name: Allen, Miss Elisabeth Walton, dtype: object

# %%
# select DataFrame rows based on some condition.

url = 'https://raw.githubusercontent.com/chrisalbon/sim_data/master/titanic.csv'

df = pd.read_csv(url)

df[df["Sex"] == "female"].head(2)
# Out:
#                            Name PClass   Age     Sex  Survived  SexCode
# 0  Allen, Miss Elisabeth Walton    1st  29.0  female         1        1
# 1   Allison, Miss Helen Loraine    1st   2.0  female         0        1

# %%
df[(df["Sex"] == "female") & (df["Age"] >= 65)]
# Out:
#                                                  Name PClass   Age     Sex  \
# 73  Crosby, Mrs Edward Gifford (Catherine Elizabet...    1st  69.0  female
#
#     Survived  SexCode
# 73         1        1

# %%
#sort a dataframe by the values in a column.

df.sort_values(by=["Age"]).head(2)
# Out:
#                                        Name PClass   Age     Sex  Survived  \
# 763  Dean, Miss Elizabeth Gladys (Millvena)    3rd  0.17  female         1
# 751  Danbom, Master Gilbert Sigvard Emanuel    3rd  0.33    male         0
#
#      SexCode
# 763        1
# 751        0

# %%
#replace values in a DataFrame.

df["Sex"].replace("female", "Woman").head(2)
# Out:
# 0    Woman
# 1    Woman
# Name: Sex, dtype: object

# %%
df["Sex"].replace(["female", "male"], ["Woman", "Man"]).head(5)
# Out:
# 0    Woman
# 1    Woman
# 2      Man
# 3    Woman
# 4      Man
# Name: Sex, dtype: object

# %%
#find and replace across the entire DataFrame

df.replace(1, "One").head(2)
# Out:
#                            Name PClass   Age     Sex Survived SexCode
# 0  Allen, Miss Elisabeth Walton    1st  29.0  female      One     One
# 1   Allison, Miss Helen Loraine    1st   2.0  female        0     One

# %%
# accepts regular expressions:

df.replace(r"1st", "First", regex=True).head(2)
# Out:
#                            Name PClass   Age     Sex  Survived  SexCode
# 0  Allen, Miss Elisabeth Walton  First  29.0  female         1        1
# 1   Allison, Miss Helen Loraine  First   2.0  female         0        1

# %%
#rename a column in a pandas DataFrame

df.rename(columns={"Pclass":"Passener Class"}).head(2)
# Out:
#                            Name PClass   Age     Sex  Survived  SexCode
# 0  Allen, Miss Elisabeth Walton    1st  29.0  female         1        1
# 1   Allison, Miss Helen Loraine    1st   2.0  female         0        1

# %%
df.rename(columns={"Pclass":"Passener Class", "Sex":"Gender"}).head(2)
# Out:
#                            Name PClass   Age  Gender  Survived  SexCode
# 0  Allen, Miss Elisabeth Walton    1st  29.0  female         1        1
# 1   Allison, Miss Helen Loraine    1st   2.0  female         0        1

# %%
import collections

column_names = collections.defaultdict(str)

for name in df.columns:
    column_names[name]

column_names
# Out:
# defaultdict(str,
#             {'Name': '',
#              'PClass': '',
#              'Age': '',
#              'Sex': '',
#              'Survived': '',
#              'SexCode': ''})

# %%
#find the min, max, sum, average, or count of a numeric column.
# var, std, kurt, skewness, skew sem, mode, median

print(df["Age"].max())
print(df["Age"].min())
print(df["Age"].mean())
print(df["Age"].sum())
print(df["Age"].count())
# Out:
# 71.0
# 0.17
# 30.397989417989418
# 22980.88
# 756

# %%
df.count()
# Out:
# Name        1313
# PClass      1313
# Age          756
# Sex         1313
# Survived    1313
# SexCode     1313
# dtype: int64

# %%
#select all unique values in a column.

df["Sex"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      851
# female    462
# Name: count, dtype: int64

# %%
df["PClass"].value_counts()
# Out:
# PClass
# 3rd    711
# 1st    322
# 2nd    279
# *        1
# Name: count, dtype: int64

# %%
df["PClass"].nunique()
# Out:
# 4

# %%
df[df["Age"].isnull()].head(2)
# Out:
#                             Name PClass  Age     Sex  Survived  SexCode
# 12  Aubert, Mrs Leontine Pauline    1st  NaN  female         1        1
# 13      Barkworth, Mr Algernon H    1st  NaN    male         1        0

# %%
df["Sex"] = df["Sex"].replace("male", np.nan)

# %%
df = pd.read_csv(url,  na_values=[np.nan, "NONE", -999])

# %%
null_entry = df[df["Age"].isna()].head(1)
print(null_entry)
# Out:
#                             Name PClass  Age     Sex  Survived  SexCode
# 12  Aubert, Mrs Leontine Pauline    1st  NaN  female         1        1

# %%
null_entry.fillna(df["Age"].mean())
# Out:
#                             Name PClass        Age     Sex  Survived  SexCode
# 12  Aubert, Mrs Leontine Pauline    1st  30.397989  female         1        1

# %%
#delete a column from your DataFrame.

df.drop("Age", axis=1).head(2)
# Out:
#                            Name PClass     Sex  Survived  SexCode
# 0  Allen, Miss Elisabeth Walton    1st  female         1        1
# 1   Allison, Miss Helen Loraine    1st  female         0        1

# %%
df.drop(["Age", "Sex"], axis=1).head(2)
# Out:
#                            Name PClass  Survived  SexCode
# 0  Allen, Miss Elisabeth Walton    1st         1        1
# 1   Allison, Miss Helen Loraine    1st         0        1

# %%
df.drop(df.columns[1], axis=1).head(2)
# Out:
#                            Name   Age     Sex  Survived  SexCode
# 0  Allen, Miss Elisabeth Walton  29.0  female         1        1
# 1   Allison, Miss Helen Loraine   2.0  female         0        1

# %%
#delete one or more rows from a DataFrame.

df[df["Sex"] != "male"].head(3)
# Out:
#                                             Name PClass   Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.0  female
# 1                    Allison, Miss Helen Loraine    1st   2.0  female
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 3         0        1

# %%
df[df["Name"] != "Allison, Miss Helen Loraine"].head(2)
# Out:
#                                   Name PClass   Age     Sex  Survived  SexCode
# 0         Allen, Miss Elisabeth Walton    1st  29.0  female         1        1
# 2  Allison, Mr Hudson Joshua Creighton    1st  30.0    male         0        0

# %%
df[df.index != 0].head(2)
# Out:
#                                   Name PClass   Age     Sex  Survived  SexCode
# 1          Allison, Miss Helen Loraine    1st   2.0  female         0        1
# 2  Allison, Mr Hudson Joshua Creighton    1st  30.0    male         0        0

# %%
#drop duplicate rows from your DataFrame.

df.drop_duplicates().head()
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0

# %%
print(len(df))
print(len(df.drop_duplicates()))
# Out:
# 1313
# 1313

# %%
df.drop_duplicates(subset=["Sex"])
# Out:
#                                   Name PClass   Age     Sex  Survived  SexCode
# 0         Allen, Miss Elisabeth Walton    1st  29.0  female         1        1
# 2  Allison, Mr Hudson Joshua Creighton    1st  30.0    male         0        0

# %%
df.drop_duplicates(subset=["Sex"], keep="last")
# Out:
#                      Name PClass   Age     Sex  Survived  SexCode
# 1307  Zabour, Miss Tamini    3rd   NaN  female         0        1
# 1312       Zimmerman, Leo    3rd  29.0    male         0        0

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1308    False
# 1309    False
# 1310    False
# 1311    False
# 1312    False
# Length: 1313, dtype: bool

# %%
#group individual rows according to some shared value.

df = pd.read_csv(url)

df.groupby("Sex").mean(numeric_only=True)
# Out:
#               Age  Survived  SexCode
# Sex
# female  29.396424  0.666667      1.0
# male    31.014338  0.166863      0.0

# %%
df.groupby("Survived")["Name"].count()
# Out:
# Survived
# 0    863
# 1    450
# Name: Name, dtype: int64

# %%
df.groupby(["Sex", "Survived"])["Age"].mean()
# Out:
# Sex     Survived
# female  0           24.901408
#         1           30.867143
# male    0           32.320780
#         1           25.951875
# Name: Age, dtype: float64

# %%
#group individual rows by time periods.

time_index = pd.date_range("06/06/2017", periods=100000, freq='30S')

df = pd.DataFrame(index=time_index)

df["Sale_Amount"] = np.random.randint(1, 10, 100000)

df.resample("W").sum()
# Out:
# <ipython-input-51-ca139bcc15ef>:3: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   time_index = pd.date_range("06/06/2017", periods=100000, freq='30S')
#             Sale_Amount
# 2017-06-11        86860
# 2017-06-18       101084
# 2017-06-25       100188
# 2017-07-02       100684
# 2017-07-09       101179
# 2017-07-16        10392

# %%
df.head()
# Out:
#                      Sale_Amount
# 2017-06-06 00:00:00            1
# 2017-06-06 00:00:30            6
# 2017-06-06 00:01:00            4
# 2017-06-06 00:01:30            2
# 2017-06-06 00:02:00            5

# %%
#resample requires the index to be a datetime-like value.

df.resample("2W").mean()
# Out:
#             Sale_Amount
# 2017-06-11     5.026620
# 2017-06-25     4.991865
# 2017-07-09     5.006523
# 2017-07-23     4.996154

# %%
df.resample("M").count()
# Out:
# <ipython-input-54-7e4132bac0e7>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.resample("M").count()
#             Sale_Amount
# 2017-06-30        72000
# 2017-07-31        28000

# %%
df.resample("M", label="left").count()
# Out:
# <ipython-input-55-905a17a6ab25>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.resample("M", label="left").count()
#             Sale_Amount
# 2017-05-31        72000
# 2017-06-30        28000

# %%
#aggregate an operation over each column (or a set of columns) in a dataframe

df = pd.read_csv(url)

df.agg("min")
# Out:
# Name        Abbing, Mr Anthony
# PClass                       *
# Age                       0.17
# Sex                     female
# Survived                     0
# SexCode                      0
# dtype: object

# %%
df.agg({"Age":["mean"], "SexCode":["min", "max"]})
# Out:
#             Age  SexCode
# mean  30.397989      NaN
# min         NaN      0.0
# max         NaN      1.0

# %%
df.groupby(["PClass", "Survived"]).agg({"Survived":["count"]}).reset_index()
# Out:
#   PClass Survived
#                   count
# 0      *        0     1
# 1    1st        0   129
# 2    1st        1   193
# 3    2nd        0   160
# 4    2nd        1   119
# 5    3rd        0   573
# 6    3rd        1   138

# %%
#iterate over every element in a column and apply some action

df = pd.read_csv(url)

for name in df["Name"][:2]:
    print(name.upper())
# Out:
# ALLEN, MISS ELISABETH WALTON
# ALLISON, MISS HELEN LORAINE

# %%
[name.upper() for name in df["Name"][:2]]
# Out:
# ['ALLEN, MISS ELISABETH WALTON', 'ALLISON, MISS HELEN LORAINE']

# %%
#pply some function over all elements in a column.

def uppercase(x):
    return x.upper()

df["Name"].apply(uppercase)[:2]
# Out:
# 0    ALLEN, MISS ELISABETH WALTON
# 1     ALLISON, MISS HELEN LORAINE
# Name: Name, dtype: object

# %%
#apply a function to each group.

df.groupby("Sex").apply(lambda x: x.count())
# Out:
# <ipython-input-63-a947bcf9c7b0>:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby("Sex").apply(lambda x: x.count())
#         Name  PClass  Age  Sex  Survived  SexCode
# Sex
# female   462     462  288  462       462      462
# male     851     851  468  851       851      851

# %%
#concatenate two DataFrames.

data_A = {"id":["1", "2", "3"],
          "first":["Alex", "Amy", "Allen"],
          "last":["Anderson", "Ackerman", "Ali"]}

df_A = pd.DataFrame(data_A, columns=["id", "first", "last"])

data_b = {'id': ['4', '5', '6'],
          'first': ['Billy', 'Brian', 'Bran'],
          'last': ['Bonder', 'Black', 'Balwner']}
dataframe_b = pd.DataFrame(data_b, columns = ['id', 'first', 'last'])

pd.concat([df_A, dataframe_b], axis = 0)
# Out:
#   id  first      last
# 0  1   Alex  Anderson
# 1  2    Amy  Ackerman
# 2  3  Allen       Ali
# 0  4  Billy    Bonder
# 1  5  Brian     Black
# 2  6   Bran   Balwner

# %%
pd.concat([df_A, dataframe_b], axis = 1)
# Out:
#   id  first      last id  first     last
# 0  1   Alex  Anderson  4  Billy   Bonder
# 1  2    Amy  Ackerman  5  Brian    Black
# 2  3  Allen       Ali  6   Bran  Balwner

# %%
#merge two DataFrames.

employee_data = {'employee_id': ['1', '2', '3', '4'],
                 'name': ['Amy Jones', 'Allen Keys', 'Alice Bees',
                 'Tim Horton']}
dataframe_employees = pd.DataFrame(employee_data, columns = ['employee_id',
                                                              'name'])

sales_data = {'employee_id': ['3', '4', '5', '6'],
              'total_sales': [23456, 2512, 2345, 1455]}
dataframe_sales = pd.DataFrame(sales_data, columns = ['employee_id',
                                                      'total_sales'])

pd.merge(dataframe_employees, dataframe_sales, on="employee_id")
# Out:
#   employee_id        name  total_sales
# 0           3  Alice Bees        23456
# 1           4  Tim Horton         2512

# %%
pd.merge(dataframe_employees, dataframe_sales, on="employee_id", how="outer")
# Out:
#   employee_id        name  total_sales
# 0           1   Amy Jones          NaN
# 1           2  Allen Keys          NaN
# 2           3  Alice Bees      23456.0
# 3           4  Tim Horton       2512.0
# 4           5         NaN       2345.0
# 5           6         NaN       1455.0

# %%
pd.merge(dataframe_employees, dataframe_sales, on="employee_id", how="left")
# Out:
#   employee_id        name  total_sales
# 0           1   Amy Jones          NaN
# 1           2  Allen Keys          NaN
# 2           3  Alice Bees      23456.0
# 3           4  Tim Horton       2512.0

# %%
pd.merge(dataframe_employees,
         dataframe_sales,
         left_on='employee_id',
         right_on='employee_id')
# Out:
#   employee_id        name  total_sales
# 0           3  Alice Bees        23456
# 1           4  Tim Horton         2512

# %% [markdown]
# * Inner - Return only the rows that match in both DataFrames
# * Outer - Return all rows in both DataFrames
# * Left - Return all rows from the left DataFrame but only rows from the right DataFrame that match with the left DataFrame
# * Right - Return all rows from the right DataFrame but only rows from the left DataFrame that match with the right DataFrame.
